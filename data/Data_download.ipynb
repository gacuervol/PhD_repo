# %% [markdown]
# # Descarga de datos WeatherBench2
# ---
#
# ``python version = 3.11``
#
# > [08/02/2024]: En este notebook se hace intenta descargar el conjunto de datos ERA 5
#
#
# En este notebook se exploran los conjuntos de datos de WeatherBench2

# %%
# !pip install apache-beam
# !pip install git+https://github.com/google-research/weatherbench2.git
# !pip install gcsfs
# !pip install netCDF4

# %%
import apache_beam
import weatherbench2
import numpy as np
import xarray as xr

# %% [markdown]
# ## ERA 5, resolución: 1440x721, niveles: 13, time step: 6 H
# ---
#
# > **Nomenclatura:** ``1959-2023_01_10-wb13-6h-1440x721_with_derived_variables``
# > * fecha inicial: ``1959``
# > * fecha final: ``2023_01_10``
# > * niveles: ``wb13``
# > * delta tiempo: ``6h``
# > * resolución espacial: ``1440x721``
# > * info. extra: ``with_derived_variables``

# %%
data_UHR = xr.open_zarr('gs://weatherbench2/datasets/era5/1959-2023_01_10-wb13-6h-1440x721_with_derived_variables.zarr')
data_UHR
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 93544,
#                                                        latitude: 721,
#                                                        longitude: 1440,
#                                                        level: 13)
# Coordinates:
#   * latitude                                          (latitude) float32 90.0...
#   * level                                             (level) int64 50 ... 1000
#   * longitude                                         (longitude) float32 0.0...
#   * time                                              (time) datetime64[ns] 1...
# Data variables: (12/62)
#     10m_u_component_of_wind                           (time, latitude, longitude) float32 ...
#     10m_v_component_of_wind                           (time, latitude, longitude) float32 ...
#     10m_wind_speed                                    (time, latitude, longitude) float32 ...
#     2m_dewpoint_temperature                           (time, latitude, longitude) float32 ...
#     2m_temperature                                    (time, latitude, longitude) float32 ...
#     above_ground                                      (time, level, latitude, longitude) float32 ...
#     ...                                                ...
#     volumetric_soil_water_layer_1                     (time, latitude, longitude) float32 ...
#     volumetric_soil_water_layer_2                     (time, latitude, longitude) float32 ...
#     volumetric_soil_water_layer_3                     (time, latitude, longitude) float32 ...
#     volumetric_soil_water_layer_4                     (time, latitude, longitude) float32 ...
#     vorticity                                         (time, level, latitude, longitude) float32 ...
#     wind_speed                                        (time, level, latitude, longitude) float32 ...

# %%
# Peso en GB
data_UHR.nbytes / 1000**3
# Out:
# 88963.00301054

# %%
data_UHR.to_netcdf(r"C:\Users\gcuervo\Documents\Doctorado\DB\1959-2023_01_10-wb13-6h-1440x721_with_derived_variables.nc")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data.to_netcdf(r"C:\Users\gcuervo\Documents\Doctorado\DB\1959-2023_01_10-wb13-6h-1440x721_with_derived_variables.nc")
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\dataset.py:1957, in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1932 @overload
#    1933 def to_netcdf(
#    1934     self,
#    (...)
#    1944     invalid_netcdf: bool = False,
#    1945 ) -> Delayed:
#    1946     ...
#    1948 def to_netcdf(
#    1949     self,
#    1950     path: str | PathLike | None = None,
#    1951     mode: Literal["w", "a"] = "w",
#    1952     format: T_NetcdfTypes | None = None,
#    1953     group: str | None = None,
#    1954     engine: T_NetcdfEngine | None = None,
#    1955     encoding: Mapping[Any, Mapping[str, Any]] | None = None,
#    1956     unlimited_dims: Iterable[Hashable] | None = None,
# -> 1957     compute: bool = True,
#    1958     invalid_netcdf: bool = False,
#    1959 ) -> bytes | Delayed | None:
#    1960     """Write dataset contents to a netCDF file.
#    1961
#    1962     Parameters
#    (...)
#    2035     DataArray.to_netcdf
#    2036     """
#    2037     if encoding is None:
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\api.py:1272, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1267         return dask.delayed(_finalize_store)(writes, store)
#    1268     return None
#    1271 def dump_to_store(
# -> 1272     dataset, store, writer=None, encoder=None, encoding=None, unlimited_dims=None
#    1273 ):
#    1274     """Store dataset contents to a backends.*DataStore object."""
#    1275     if writer is None:
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\api.py:1319, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1296 def save_mfdataset(
#    1297     datasets,
#    1298     paths,
#    (...)
#    1304     **kwargs,
#    1305 ):
#    1306     """Write multiple datasets to disk as netCDF files simultaneously.
#    1307
#    1308     This function is intended for use with datasets consisting of dask.array
#    1309     objects, in which case it can write the multiple datasets to disk
#    1310     simultaneously using a shared thread pool.
#    1311
#    1312     When not using dask, it is no different than calling ``to_netcdf``
#    1313     repeatedly.
#    1314
#    1315     Parameters
#    1316     ----------
#    1317     datasets : list of Dataset
#    1318         List of datasets to save.
# -> 1319     paths : list of str or list of path-like objects
#    1320         List of paths to which to save each corresponding dataset.
#    1321     mode : {"w", "a"}, optional
#    1322         Write ("w") or append ("a") mode. If mode="w", any existing file at
#    1323         these locations will be overwritten.
#    1324     format : {"NETCDF4", "NETCDF4_CLASSIC", "NETCDF3_64BIT", \
#    1325               "NETCDF3_CLASSIC"}, optional
#    1326     **kwargs : additional arguments are passed along to ``to_netcdf``
#    1327
#    1328         File format for the resulting netCDF file:
#    1329
#    1330         * NETCDF4: Data is stored in an HDF5 file, using netCDF4 API
#    1331           features.
#    1332         * NETCDF4_CLASSIC: Data is stored in an HDF5 file, using only
#    1333           netCDF 3 compatible API features.
#    1334         * NETCDF3_64BIT: 64-bit offset version of the netCDF 3 file format,
#    1335           which fully supports 2+ GB files, but is only compatible with
#    1336           clients linked against netCDF version 3.6.0 or later.
#    1337         * NETCDF3_CLASSIC: The classic netCDF 3 file format. It does not
#    1338           handle 2+ GB files very well.
#    1339
#    1340         All formats are supported by the netCDF4-python library.
#    1341         scipy.io.netcdf only supports the last two formats.
#    1342
#    1343         The default format is NETCDF4 if you are saving a file to disk and
#    1344         have the netCDF4-python library available. Otherwise, xarray falls
#    1345         back to using scipy to write netCDF files and defaults to the
#    1346         NETCDF3_64BIT format (scipy does not support netCDF4).
#    1347     groups : list of str, optional
#    1348         Paths to the netCDF4 group in each corresponding file to which to save
#    1349         datasets (only works for format="NETCDF4"). The groups will be created
#    1350         if necessary.
#    1351     engine : {"netcdf4", "scipy", "h5netcdf"}, optional
#    1352         Engine to use when writing netCDF files. If not provided, the
#    1353         default engine is chosen based on available dependencies, with a
#    1354         preference for "netcdf4" if writing to a file on disk.
#    1355         See `Dataset.to_netcdf` for additional information.
#    1356     compute : bool
#    1357         If true compute immediately, otherwise return a
#    1358         ``dask.delayed.Delayed`` object that can be computed later.
#    1359
#    1360     Examples
#    1361     --------
#    1362
#    1363     Save a dataset into one netCDF per year of data:
#    1364
#    1365     >>> ds = xr.Dataset(
#    1366     ...     {"a": ("time", np.linspace(0, 1, 48))},
#    1367     ...     coords={"time": pd.date_range("2010-01-01", freq="M", periods=48)},
#    1368     ... )
#    1369     >>> ds
#    1370     <xarray.Dataset>
#    1371     Dimensions:  (time: 48)
#    1372     Coordinates:
#    1373       * time     (time) datetime64[ns] 2010-01-31 2010-02-28 ... 2013-12-31
#    1374     Data variables:
#    1375         a        (time) float64 0.0 0.02128 0.04255 0.06383 ... 0.9574 0.9787 1.0
#    1376     >>> years, datasets = zip(*ds.groupby("time.year"))
#    1377     >>> paths = [f"{y}.nc" for y in years]
#    1378     >>> xr.save_mfdataset(datasets, paths)
#    1379     """
#    1380     if mode == "w" and len(set(paths)) < len(paths):
#    1381         raise ValueError(
#    1382             "cannot use mode='w' when writing multiple datasets to the same path"
#    1383         )
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\common.py:274, in store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     271 class AbstractWritableDataStore(AbstractDataStore):
#     272     __slots__ = ()
# --> 274     def encode(self, variables, attributes):
#     275         """
#     276         Encode the variables and attributes in this store
#     277
#    (...)
#     289
#     290         """
#     291         variables = {k: self.encode_variable(v) for k, v in variables.items()}
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\common.py:363, in encode(self, variables, attributes)
#     360 def set_attributes(self, attributes):
#     361     """
#     362     This provides a centralized method to set the dataset attributes on the
# --> 363     data store.
#     364
#     365     Parameters
#     366     ----------
#     367     attributes : dict-like
#     368         Dictionary of key/value (attribute name / attribute) pairs
#     369     """
#     370     for k, v in attributes.items():
#     371         self.set_attribute(k, v)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:779, in cf_encoder(variables, attributes)
#     776 # add encoding for time bounds variables if present.
#     777 _update_bounds_encoding(variables)
# --> 779 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     781 # Remove attrs from bounds variables (issue #2921)
#     782 for var in new_vars.values():
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:779, in <dictcomp>(.0)
#     776 # add encoding for time bounds variables if present.
#     777 _update_bounds_encoding(variables)
# --> 779 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     781 # Remove attrs from bounds variables (issue #2921)
#     782 for var in new_vars.values():
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:190, in encode_cf_variable(var, needs_copy, name)
#     178 ensure_not_multiindex(var, name=name)
#     180 for coder in [
#     181     times.CFDatetimeCoder(),
#     182     times.CFTimedeltaCoder(),
#    (...)
#     188     variables.BooleanCoder(),
#     189 ]:
# --> 190     var = coder.encode(var, name=name)
#     192 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     193 var = ensure_dtype_not_object(var, name=name)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\coding\times.py:703, in CFDatetimeCoder.encode(self, variable, name)
#     701 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     702     if np.issubdtype(
# --> 703         variable.data.dtype, np.datetime64
#     704     ) or contains_cftime_datetimes(variable):
#     705         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     707         (data, units, calendar) = encode_cf_datetime(
#     708             data, encoding.pop("units", None), encoding.pop("calendar", None)
#     709         )
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\variable.py:435, in Variable.data(self)
#     433     return self._data
#     434 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 435     return self._data.get_duck_array()
#     436 else:
#     437     return self.values
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:696, in MemoryCachedArray.get_duck_array(self)
#     695 def get_duck_array(self):
# --> 696     self._ensure_cached()
#     697     return self.array.get_duck_array()
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:690, in MemoryCachedArray._ensure_cached(self)
#     689 def _ensure_cached(self):
# --> 690     self.array = as_indexable(self.array.get_duck_array())
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:664, in CopyOnWriteArray.get_duck_array(self)
#     663 def get_duck_array(self):
# --> 664     return self.array.get_duck_array()
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:551, in LazilyIndexedArray.get_duck_array(self)
#     550 def get_duck_array(self):
# --> 551     array = self.array[self.key]
#     552     # self.array[self.key] is now a numpy array when
#     553     # self.array is a BackendArray subclass
#     554     # and self.key is BasicIndexer((slice(None, None, None),))
#     555     # so we need the explicit check for ExplicitlyIndexed
#     556     if isinstance(array, ExplicitlyIndexed):
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\zarr.py:92, in ZarrArrayWrapper.__getitem__(self, key)
#      90 array = self.get_array()
#      91 if isinstance(key, indexing.BasicIndexer):
# ---> 92     return array[key.tuple]
#      93 elif isinstance(key, indexing.VectorizedIndexer):
#      94     return array.vindex[
#      95         indexing._arrayize_vectorized_indexer(key, self.shape).tuple
#      96     ]
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:842, in Array.__getitem__(self, selection)
#     840     result = self.vindex[selection]
#     841 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 842     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     843 else:
#     844     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:1124, in Array.get_orthogonal_selection(self, selection, out, fields)
#    1121 # setup indexer
#    1122 indexer = OrthogonalIndexer(selection, self)
# -> 1124 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:1377, in Array._get_selection(self, indexer, out, fields)
#    1375 # setup output array
#    1376 if out is None:
# -> 1377     out = np.empty_like(
#    1378         self._meta_array, shape=out_shape, dtype=out_dtype, order=self._order
#    1379     )
#    1380 else:
#    1381     check_array_shape("out", out, out_shape)
#
# MemoryError: Unable to allocate 362. GiB for an array with shape (93544, 721, 1440) and data type float32

# %% [markdown]
# La base de datos pesa ``88.963 GB`` por lo que no es posible guardarla en local.

# %% [markdown]
# ### Selección de variables
# ---
# Debido a que la base de datos es demasiado grande se intenta seleccionar solo unas cuantas variables ver si se puede descargar en local.

# %%
data_sel_vars = data_UHR[['geopotential', 'temperature', 'specific_humidity', 'u_component_of_wind', 'v_component_of_wind']]
data_sel_vars
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 93544, level: 13, latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude             (latitude) float32 90.0 89.75 89.5 ... -89.75 -90.0
#   * level                (level) int64 50 100 150 200 250 ... 700 850 925 1000
#   * longitude            (longitude) float32 0.0 0.25 0.5 ... 359.2 359.5 359.8
#   * time                 (time) datetime64[ns] 1959-01-01 ... 2023-01-10T18:0...
# Data variables:
#     geopotential         (time, level, latitude, longitude) float32 ...
#     temperature          (time, level, latitude, longitude) float32 ...
#     specific_humidity    (time, level, latitude, longitude) float32 ...
#     u_component_of_wind  (time, level, latitude, longitude) float32 ...
#     v_component_of_wind  (time, level, latitude, longitude) float32 ...

# %%
# Peso en GB
data_sel_vars.nbytes / 1000**3
# Out:
# 25251.4926227

# %%
data_sel_vars.to_netcdf(r"C:\Users\gcuervo\Documents\Doctorado\DB\1959-2023_01_10-wb13-6h-1440x721_with_geop_temp_spehum_uvwind.nc")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 data_sel_vars.to_netcdf(r"C:\Users\gcuervo\Documents\Doctorado\DB\1959-2023_01_10-wb13-6h-1440x721_with_geop_temp_spehum_uvwind.nc")
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\dataset.py:1957, in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1932 @overload
#    1933 def to_netcdf(
#    1934     self,
#    (...)
#    1944     invalid_netcdf: bool = False,
#    1945 ) -> Delayed:
#    1946     ...
#    1948 def to_netcdf(
#    1949     self,
#    1950     path: str | PathLike | None = None,
#    1951     mode: Literal["w", "a"] = "w",
#    1952     format: T_NetcdfTypes | None = None,
#    1953     group: str | None = None,
#    1954     engine: T_NetcdfEngine | None = None,
#    1955     encoding: Mapping[Any, Mapping[str, Any]] | None = None,
#    1956     unlimited_dims: Iterable[Hashable] | None = None,
# -> 1957     compute: bool = True,
#    1958     invalid_netcdf: bool = False,
#    1959 ) -> bytes | Delayed | None:
#    1960     """Write dataset contents to a netCDF file.
#    1961
#    1962     Parameters
#    (...)
#    2035     DataArray.to_netcdf
#    2036     """
#    2037     if encoding is None:
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\api.py:1272, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1267         return dask.delayed(_finalize_store)(writes, store)
#    1268     return None
#    1271 def dump_to_store(
# -> 1272     dataset, store, writer=None, encoder=None, encoding=None, unlimited_dims=None
#    1273 ):
#    1274     """Store dataset contents to a backends.*DataStore object."""
#    1275     if writer is None:
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\api.py:1319, in dump_to_store(dataset, store, writer, encoder, encoding, unlimited_dims)
#    1296 def save_mfdataset(
#    1297     datasets,
#    1298     paths,
#    (...)
#    1304     **kwargs,
#    1305 ):
#    1306     """Write multiple datasets to disk as netCDF files simultaneously.
#    1307
#    1308     This function is intended for use with datasets consisting of dask.array
#    1309     objects, in which case it can write the multiple datasets to disk
#    1310     simultaneously using a shared thread pool.
#    1311
#    1312     When not using dask, it is no different than calling ``to_netcdf``
#    1313     repeatedly.
#    1314
#    1315     Parameters
#    1316     ----------
#    1317     datasets : list of Dataset
#    1318         List of datasets to save.
# -> 1319     paths : list of str or list of path-like objects
#    1320         List of paths to which to save each corresponding dataset.
#    1321     mode : {"w", "a"}, optional
#    1322         Write ("w") or append ("a") mode. If mode="w", any existing file at
#    1323         these locations will be overwritten.
#    1324     format : {"NETCDF4", "NETCDF4_CLASSIC", "NETCDF3_64BIT", \
#    1325               "NETCDF3_CLASSIC"}, optional
#    1326     **kwargs : additional arguments are passed along to ``to_netcdf``
#    1327
#    1328         File format for the resulting netCDF file:
#    1329
#    1330         * NETCDF4: Data is stored in an HDF5 file, using netCDF4 API
#    1331           features.
#    1332         * NETCDF4_CLASSIC: Data is stored in an HDF5 file, using only
#    1333           netCDF 3 compatible API features.
#    1334         * NETCDF3_64BIT: 64-bit offset version of the netCDF 3 file format,
#    1335           which fully supports 2+ GB files, but is only compatible with
#    1336           clients linked against netCDF version 3.6.0 or later.
#    1337         * NETCDF3_CLASSIC: The classic netCDF 3 file format. It does not
#    1338           handle 2+ GB files very well.
#    1339
#    1340         All formats are supported by the netCDF4-python library.
#    1341         scipy.io.netcdf only supports the last two formats.
#    1342
#    1343         The default format is NETCDF4 if you are saving a file to disk and
#    1344         have the netCDF4-python library available. Otherwise, xarray falls
#    1345         back to using scipy to write netCDF files and defaults to the
#    1346         NETCDF3_64BIT format (scipy does not support netCDF4).
#    1347     groups : list of str, optional
#    1348         Paths to the netCDF4 group in each corresponding file to which to save
#    1349         datasets (only works for format="NETCDF4"). The groups will be created
#    1350         if necessary.
#    1351     engine : {"netcdf4", "scipy", "h5netcdf"}, optional
#    1352         Engine to use when writing netCDF files. If not provided, the
#    1353         default engine is chosen based on available dependencies, with a
#    1354         preference for "netcdf4" if writing to a file on disk.
#    1355         See `Dataset.to_netcdf` for additional information.
#    1356     compute : bool
#    1357         If true compute immediately, otherwise return a
#    1358         ``dask.delayed.Delayed`` object that can be computed later.
#    1359
#    1360     Examples
#    1361     --------
#    1362
#    1363     Save a dataset into one netCDF per year of data:
#    1364
#    1365     >>> ds = xr.Dataset(
#    1366     ...     {"a": ("time", np.linspace(0, 1, 48))},
#    1367     ...     coords={"time": pd.date_range("2010-01-01", freq="M", periods=48)},
#    1368     ... )
#    1369     >>> ds
#    1370     <xarray.Dataset>
#    1371     Dimensions:  (time: 48)
#    1372     Coordinates:
#    1373       * time     (time) datetime64[ns] 2010-01-31 2010-02-28 ... 2013-12-31
#    1374     Data variables:
#    1375         a        (time) float64 0.0 0.02128 0.04255 0.06383 ... 0.9574 0.9787 1.0
#    1376     >>> years, datasets = zip(*ds.groupby("time.year"))
#    1377     >>> paths = [f"{y}.nc" for y in years]
#    1378     >>> xr.save_mfdataset(datasets, paths)
#    1379     """
#    1380     if mode == "w" and len(set(paths)) < len(paths):
#    1381         raise ValueError(
#    1382             "cannot use mode='w' when writing multiple datasets to the same path"
#    1383         )
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\common.py:274, in store(self, variables, attributes, check_encoding_set, writer, unlimited_dims)
#     271 class AbstractWritableDataStore(AbstractDataStore):
#     272     __slots__ = ()
# --> 274     def encode(self, variables, attributes):
#     275         """
#     276         Encode the variables and attributes in this store
#     277
#    (...)
#     289
#     290         """
#     291         variables = {k: self.encode_variable(v) for k, v in variables.items()}
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\common.py:363, in encode(self, variables, attributes)
#     360 def set_attributes(self, attributes):
#     361     """
#     362     This provides a centralized method to set the dataset attributes on the
# --> 363     data store.
#     364
#     365     Parameters
#     366     ----------
#     367     attributes : dict-like
#     368         Dictionary of key/value (attribute name / attribute) pairs
#     369     """
#     370     for k, v in attributes.items():
#     371         self.set_attribute(k, v)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:779, in cf_encoder(variables, attributes)
#     776 # add encoding for time bounds variables if present.
#     777 _update_bounds_encoding(variables)
# --> 779 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     781 # Remove attrs from bounds variables (issue #2921)
#     782 for var in new_vars.values():
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:779, in <dictcomp>(.0)
#     776 # add encoding for time bounds variables if present.
#     777 _update_bounds_encoding(variables)
# --> 779 new_vars = {k: encode_cf_variable(v, name=k) for k, v in variables.items()}
#     781 # Remove attrs from bounds variables (issue #2921)
#     782 for var in new_vars.values():
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\conventions.py:190, in encode_cf_variable(var, needs_copy, name)
#     178 ensure_not_multiindex(var, name=name)
#     180 for coder in [
#     181     times.CFDatetimeCoder(),
#     182     times.CFTimedeltaCoder(),
#    (...)
#     188     variables.BooleanCoder(),
#     189 ]:
# --> 190     var = coder.encode(var, name=name)
#     192 # TODO(kmuehlbauer): check if ensure_dtype_not_object can be moved to backends:
#     193 var = ensure_dtype_not_object(var, name=name)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\coding\times.py:703, in CFDatetimeCoder.encode(self, variable, name)
#     701 def encode(self, variable: Variable, name: T_Name = None) -> Variable:
#     702     if np.issubdtype(
# --> 703         variable.data.dtype, np.datetime64
#     704     ) or contains_cftime_datetimes(variable):
#     705         dims, data, attrs, encoding = unpack_for_encoding(variable)
#     707         (data, units, calendar) = encode_cf_datetime(
#     708             data, encoding.pop("units", None), encoding.pop("calendar", None)
#     709         )
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\variable.py:435, in Variable.data(self)
#     433     return self._data
#     434 elif isinstance(self._data, indexing.ExplicitlyIndexed):
# --> 435     return self._data.get_duck_array()
#     436 else:
#     437     return self.values
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:696, in MemoryCachedArray.get_duck_array(self)
#     695 def get_duck_array(self):
# --> 696     self._ensure_cached()
#     697     return self.array.get_duck_array()
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:690, in MemoryCachedArray._ensure_cached(self)
#     689 def _ensure_cached(self):
# --> 690     self.array = as_indexable(self.array.get_duck_array())
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:664, in CopyOnWriteArray.get_duck_array(self)
#     663 def get_duck_array(self):
# --> 664     return self.array.get_duck_array()
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\core\indexing.py:551, in LazilyIndexedArray.get_duck_array(self)
#     550 def get_duck_array(self):
# --> 551     array = self.array[self.key]
#     552     # self.array[self.key] is now a numpy array when
#     553     # self.array is a BackendArray subclass
#     554     # and self.key is BasicIndexer((slice(None, None, None),))
#     555     # so we need the explicit check for ExplicitlyIndexed
#     556     if isinstance(array, ExplicitlyIndexed):
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\xarray\backends\zarr.py:92, in ZarrArrayWrapper.__getitem__(self, key)
#      90 array = self.get_array()
#      91 if isinstance(key, indexing.BasicIndexer):
# ---> 92     return array[key.tuple]
#      93 elif isinstance(key, indexing.VectorizedIndexer):
#      94     return array.vindex[
#      95         indexing._arrayize_vectorized_indexer(key, self.shape).tuple
#      96     ]
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:842, in Array.__getitem__(self, selection)
#     840     result = self.vindex[selection]
#     841 elif is_pure_orthogonal_indexing(pure_selection, self.ndim):
# --> 842     result = self.get_orthogonal_selection(pure_selection, fields=fields)
#     843 else:
#     844     result = self.get_basic_selection(pure_selection, fields=fields)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:1124, in Array.get_orthogonal_selection(self, selection, out, fields)
#    1121 # setup indexer
#    1122 indexer = OrthogonalIndexer(selection, self)
# -> 1124 return self._get_selection(indexer=indexer, out=out, fields=fields)
#
# File c:\Users\gcuervo\miniconda3\envs\art1_pyenv\Lib\site-packages\zarr\core.py:1377, in Array._get_selection(self, indexer, out, fields)
#    1375 # setup output array
#    1376 if out is None:
# -> 1377     out = np.empty_like(
#    1378         self._meta_array, shape=out_shape, dtype=out_dtype, order=self._order
#    1379     )
#    1380 else:
#    1381     check_array_shape("out", out, out_shape)
#
# MemoryError: Unable to allocate 4.59 TiB for an array with shape (93544, 13, 721, 1440) and data type float32

# %% [markdown]
# De la base de datos total se seleccionaron 5 variables: ``'geopotential', 'temperature', 'specific_humidity', 'u_component_of_wind', 'v_component_of_wind'``
# Con un peso de: ``25251.5 GB``

# %% [markdown]
# ## ERA 5, resolución: 512x256, niveles: 13, time step: 6 H
# ---

# %%
data_HR = xr.open_zarr('gs://weatherbench2/datasets/era5/1959-2022-6h-512x256_equiangular_conservative.zarr')
data_HR
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 92044,
#                                                        longitude: 512,
#                                                        latitude: 256, level: 13)
# Coordinates:
#   * latitude                                          (latitude) float64 -89....
#   * level                                             (level) int64 50 ... 1000
#   * longitude                                         (longitude) float64 0.0...
#   * time                                              (time) datetime64[ns] 1...
# Data variables: (12/38)
#     10m_u_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_v_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_wind_speed                                    (time, longitude, latitude) float32 ...
#     2m_temperature                                    (time, longitude, latitude) float32 ...
#     angle_of_sub_gridscale_orography                  (longitude, latitude) float32 ...
#     anisotropy_of_sub_gridscale_orography             (longitude, latitude) float32 ...
#     ...                                                ...
#     type_of_high_vegetation                           (longitude, latitude) float32 ...
#     type_of_low_vegetation                            (longitude, latitude) float32 ...
#     u_component_of_wind                               (time, level, longitude, latitude) float32 ...
#     v_component_of_wind                               (time, level, longitude, latitude) float32 ...
#     vertical_velocity                                 (time, level, longitude, latitude) float32 ...
#     wind_speed                                        (time, level, longitude, latitude) float32 ...

# %%
# Peso en GB
data_HR.nbytes / 1000**3
# Out:
# 5211.825067208

# %% [markdown]
# ## ERA 5, resolución: 240x121, niveles: 13, time step: 6 H
# ---

# %%
data_MR = xr.open_zarr('gs://weatherbench2/datasets/era5/1959-2023_01_10-6h-240x121_equiangular_with_poles_conservative.zarr')
data_MR
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 93544,
#                                                        longitude: 240,
#                                                        latitude: 121, level: 13)
# Coordinates:
#   * latitude                                          (latitude) float64 -90....
#   * level                                             (level) int64 50 ... 1000
#   * longitude                                         (longitude) float64 0.0...
#   * time                                              (time) datetime64[ns] 1...
# Data variables: (12/62)
#     10m_u_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_v_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_wind_speed                                    (time, longitude, latitude) float32 ...
#     2m_dewpoint_temperature                           (time, longitude, latitude) float32 ...
#     2m_temperature                                    (time, longitude, latitude) float32 ...
#     above_ground                                      (time, level, longitude, latitude) float32 ...
#     ...                                                ...
#     volumetric_soil_water_layer_1                     (time, longitude, latitude) float32 ...
#     volumetric_soil_water_layer_2                     (time, longitude, latitude) float32 ...
#     volumetric_soil_water_layer_3                     (time, longitude, latitude) float32 ...
#     volumetric_soil_water_layer_4                     (time, longitude, latitude) float32 ...
#     vorticity                                         (time, level, longitude, latitude) float32 ...
#     wind_speed                                        (time, level, longitude, latitude) float32 ...

# %%
# Peso en GB
data_MR.nbytes / 1000**3
# Out:
# 2488.332529584

# %% [markdown]
# ## ERA 5, resolución: 128x64, niveles: 13, time step: 6 H
# ---

# %%
data_LR = xr.open_zarr('gs://weatherbench2/datasets/era5/1959-2022-6h-128x64_equiangular_conservative.zarr')
data_LR
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 92044,
#                                                        longitude: 128,
#                                                        latitude: 64, level: 13)
# Coordinates:
#   * latitude                                          (latitude) float64 -88....
#   * level                                             (level) int64 50 ... 1000
#   * longitude                                         (longitude) float64 0.0...
#   * time                                              (time) datetime64[ns] 1...
# Data variables: (12/38)
#     10m_u_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_v_component_of_wind                           (time, longitude, latitude) float32 ...
#     10m_wind_speed                                    (time, longitude, latitude) float32 ...
#     2m_temperature                                    (time, longitude, latitude) float32 ...
#     angle_of_sub_gridscale_orography                  (longitude, latitude) float32 ...
#     anisotropy_of_sub_gridscale_orography             (longitude, latitude) float32 ...
#     ...                                                ...
#     type_of_high_vegetation                           (longitude, latitude) float32 ...
#     type_of_low_vegetation                            (longitude, latitude) float32 ...
#     u_component_of_wind                               (time, level, longitude, latitude) float32 ...
#     v_component_of_wind                               (time, level, longitude, latitude) float32 ...
#     vertical_velocity                                 (time, level, longitude, latitude) float32 ...
#     wind_speed                                        (time, level, longitude, latitude) float32 ...

# %%
# Peso en GB
data_LR.nbytes / 1000**3
# Out:
# 325.73975828

# %% [markdown]
# ## ERA 5, resolución: 64x32, niveles: 13, time step: 6 H
# ---

# %%
data_ULR = xr.open_zarr(
    'gs://weatherbench2/datasets/era5/1959-2023_01_10-6h-64x32_equiangular_conservative.zarr')
data_ULR
# Out:
# <xarray.Dataset>
# Dimensions:                                           (time: 93544,
#                                                        longitude: 64,
#                                                        latitude: 32, level: 13)
# Coordinates:
#   * latitude                                          (latitude) float64 -87....
#   * level                                             (level) int64 50 ... 1000
#   * longitude                                         (longitude) float64 0.0...
#   * time                                              (time) datetime64[ns] 1...
# Data variables: (12/62)
#     10m_u_component_of_wind                           (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     10m_v_component_of_wind                           (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     10m_wind_speed                                    (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     2m_dewpoint_temperature                           (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     2m_temperature                                    (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     above_ground                                      (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     ...                                                ...
#     volumetric_soil_water_layer_1                     (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     volumetric_soil_water_layer_2                     (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     volumetric_soil_water_layer_3                     (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     volumetric_soil_water_layer_4                     (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     vorticity                                         (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     wind_speed                                        (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>

# %%
# Peso en GB
data_ULR.nbytes / 1000**3
# Out:
# 175.486406312

# %% [markdown]
# ### Variables filtradas
# ---

# %%
data_sel_vars = data_ULR[['geopotential', 'temperature',
                          'specific_humidity', 'u_component_of_wind', 'v_component_of_wind']]
data_sel_vars
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 93544, level: 13, longitude: 64, latitude: 32)
# Coordinates:
#   * latitude             (latitude) float64 -87.19 -81.56 -75.94 ... 81.56 87.19
#   * level                (level) int64 50 100 150 200 250 ... 700 850 925 1000
#   * longitude            (longitude) float64 0.0 5.625 11.25 ... 348.8 354.4
#   * time                 (time) datetime64[ns] 1959-01-01 ... 2023-01-10T18:0...
# Data variables:
#     geopotential         (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     temperature          (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     specific_humidity    (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     u_component_of_wind  (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>
#     v_component_of_wind  (time, level, longitude, latitude) float32 dask.array<chunksize=(100, 13, 64, 32), meta=np.ndarray>

# %%
# Peso en GB
data_sel_vars.nbytes / 1000**3
# Out:
# 49.811058344

# %%
data_sel_vars_2010_2023 = data_sel_vars.sel(time=slice('2010', '2023'))
data_sel_vars_2010_2023
# Out:
# <xarray.Dataset>
# Dimensions:              (time: 19032, level: 13, longitude: 64, latitude: 32)
# Coordinates:
#   * latitude             (latitude) float64 -87.19 -81.56 -75.94 ... 81.56 87.19
#   * level                (level) int64 50 100 150 200 250 ... 700 850 925 1000
#   * longitude            (longitude) float64 0.0 5.625 11.25 ... 348.8 354.4
#   * time                 (time) datetime64[ns] 2010-01-01 ... 2023-01-10T18:0...
# Data variables:
#     geopotential         (time, level, longitude, latitude) float32 dask.array<chunksize=(88, 13, 64, 32), meta=np.ndarray>
#     temperature          (time, level, longitude, latitude) float32 dask.array<chunksize=(88, 13, 64, 32), meta=np.ndarray>
#     specific_humidity    (time, level, longitude, latitude) float32 dask.array<chunksize=(88, 13, 64, 32), meta=np.ndarray>
#     u_component_of_wind  (time, level, longitude, latitude) float32 dask.array<chunksize=(88, 13, 64, 32), meta=np.ndarray>
#     v_component_of_wind  (time, level, longitude, latitude) float32 dask.array<chunksize=(88, 13, 64, 32), meta=np.ndarray>

# %%
data_sel_vars_2010_2023.nbytes / 1000**3
# Out:
# 10.134312488

# %%
data_sel_vars_2010_2023.to_netcdf(
    r"C:\Users\gcuervo\OneDrive - Universidad de Las Palmas de Gran Canaria\Documents\Doctorado\DB\2010-2023_01_10-6h-64x32_vars_filtered.nc")

# %% [markdown]
# ### Variables superficiales filtradas
# ---

# %%
data_sel_surfvars = data_ULR[[
    '2m_temperature', 'surface_pressure', '10m_wind_speed', 'total_precipitation_6hr']]
data_sel_surfvars
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 93544, longitude: 64, latitude: 32)
# Coordinates:
#   * latitude                 (latitude) float64 -87.19 -81.56 ... 81.56 87.19
#   * longitude                (longitude) float64 0.0 5.625 11.25 ... 348.8 354.4
#   * time                     (time) datetime64[ns] 1959-01-01 ... 2023-01-10T...
# Data variables:
#     2m_temperature           (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     surface_pressure         (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     10m_wind_speed           (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>
#     total_precipitation_6hr  (time, longitude, latitude) float32 dask.array<chunksize=(100, 64, 32), meta=np.ndarray>

# %%
data_sel_surfvars_2010_2023 = data_sel_surfvars.sel(time=slice('2010', '2023'))
data_sel_surfvars_2010_2023
# Out:
# <xarray.Dataset>
# Dimensions:                  (time: 19032, longitude: 64, latitude: 32)
# Coordinates:
#   * latitude                 (latitude) float64 -87.19 -81.56 ... 81.56 87.19
#   * longitude                (longitude) float64 0.0 5.625 11.25 ... 348.8 354.4
#   * time                     (time) datetime64[ns] 2010-01-01 ... 2023-01-10T...
# Data variables:
#     2m_temperature           (time, longitude, latitude) float32 dask.array<chunksize=(88, 64, 32), meta=np.ndarray>
#     surface_pressure         (time, longitude, latitude) float32 dask.array<chunksize=(88, 64, 32), meta=np.ndarray>
#     10m_wind_speed           (time, longitude, latitude) float32 dask.array<chunksize=(88, 64, 32), meta=np.ndarray>
#     total_precipitation_6hr  (time, longitude, latitude) float32 dask.array<chunksize=(88, 64, 32), meta=np.ndarray>

# %%
# Peso en GB
data_sel_surfvars_2010_2023.nbytes / 1000**3
# Out:
# 0.6237936

# %%
data_sel_surfvars_2010_2023.to_netcdf(
    r"C:\Users\gcuervo\OneDrive - Universidad de Las Palmas de Gran Canaria\Documents\Doctorado\DB\2010-2023_01_10-6h-64x32_surfvars_filtered.nc")
