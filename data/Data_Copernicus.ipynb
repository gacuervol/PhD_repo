# %%
# !pip install copernicusmarine

# %%
import xarray as xr
import copernicusmarine
print(copernicusmarine.__version__)
# Out:
# 1.0.2

# %%
username = 
password = 
copernicusmarine.login(username=username, password=password)
# Out:
# INFO - 2024-02-15T12:09:50Z - Credentials file stored in C:\Users\gcuervo\.copernicusmarine\.copernicusmarine-credentials.
# True

# %%
# Load xarray dataset
GLOBAL_MULTIYEAR_PHY = copernicusmarine.open_dataset(dataset_id="cmems_mod_glo_phy_my_0.083deg_P1M-m",
                                                     force_dataset_version="202311",
                                                     variables=["mlotst",  "thetao", "uo", "vo",],
                                                     minimum_longitude=-180,
                                                     maximum_longitude=179.9166717529297,
                                                     minimum_latitude=-80,
                                                     maximum_latitude=90,
                                                     start_datetime="2021-06-01T00:00:00",
                                                     end_datetime="2021-06-01T00:00:00",
                                                     minimum_depth=0.49402499198913574,
                                                     maximum_depth=1000,
                                                     )


# Print loaded dataset information
GLOBAL_MULTIYEAR_PHY
# Out:
# WARNING - 2024-02-15T12:26:31Z - 'force_dataset_version' has been deprecated, use 'dataset_version' instead
# INFO - 2024-02-15T12:26:32Z - You forced selection of dataset version "202311"
# INFO - 2024-02-15T12:26:32Z - Dataset part was not specified, the first one was selected: "default"
# INFO - 2024-02-15T12:26:33Z - Service was not specified, the default one was selected: "arco-geo-series"
# <xarray.Dataset>
# Dimensions:    (depth: 35, latitude: 2041, longitude: 4320, time: 1)
# Coordinates:
#   * depth      (depth) float32 0.494 1.541 2.646 3.819 ... 643.6 763.3 902.3
#   * latitude   (latitude) float32 -80.0 -79.92 -79.83 ... 89.83 89.92 90.0
#   * longitude  (longitude) float32 -180.0 -179.9 -179.8 ... 179.8 179.8 179.9
#   * time       (time) datetime64[ns] 2021-06-01
# Data variables:
#     mlotst     (time, latitude, longitude) float32 ...
#     thetao     (time, depth, latitude, longitude) float32 ...
#     uo         (time, depth, latitude, longitude) float32 ...
#     vo         (time, depth, latitude, longitude) float32 ...
# Attributes: (12/14)
#     Conventions:                   CF-1.6
#     area:                          GLOBAL
#     contact:                       servicedesk.cmems@mercator-ocean.eu
#     credit:                        E.U. Copernicus Marine Service Information...
#     dataset:                       global-reanalysis-001-030-monthly
#     institution:                   Mercator Ocean
#     ...                            ...
#     product:                       GLOBAL_REANALYSIS_001_030
#     product_user_manual:           http://marine.copernicus.eu/documents/PUM/...
#     quality_information_document:  http://marine.copernicus.eu/documents/QUID...
#     references:                    http://marine.copernicus.eu
#     source:                        MERCATOR GLORYS12V1
#     title:                         Monthly mean fields for product GLOBAL_REA...
